# %%
import numpy as np 
import pandas as pd
from warnings import simplefilter
simplefilter(action='ignore')
from sklearn.preprocessing import MinMaxScaler

import tensorflow
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
from keras.optimizers import SGD

from plotting import SpatialPlot

# %%
train_reg = pd.read_csv('/home/nishant/Desktop/Semester 6/CS6910/Assignments/Assignment 1/data/function_approx/train.csv')
val_reg = pd.read_csv('/home/nishant/Desktop/Semester 6/CS6910/Assignments/Assignment 1/data/function_approx/val.csv')

X_train = train_reg[['x1', 'x2']].values.reshape((-1, 2))
y_train = train_reg['y'].values.reshape((-1, 1))

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
y_train = scaler.fit_transform(y_train)

# %%
model = Sequential()
model.add(Dense(8, activation='relu', input_dim=2))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='relu'))

model.compile(loss='mse', optimizer=SGD(lr=1.0, momentum=0.9), metrics=['mse'])

# %%
model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 0s 993us/step - loss: 0.5544 - mse: 0.5544
# Epoch 2/20
# 100/100 [==============================] - 0s 55us/step - loss: 0.2778 - mse: 0.2778
# Epoch 3/20
# 100/100 [==============================] - 0s 61us/step - loss: 0.2778 - mse: 0.2778
# Epoch 4/20
# 100/100 [==============================] - 0s 74us/step - loss: 0.2778 - mse: 0.2778
# Epoch 5/20
# 100/100 [==============================] - 0s 51us/step - loss: 0.2778 - mse: 0.2778
# Epoch 6/20
# 100/100 [==============================] - 0s 67us/step - loss: 0.2778 - mse: 0.2778
# Epoch 7/20
# 100/100 [==============================] - 0s 58us/step - loss: 0.2778 - mse: 0.2778
# Epoch 8/20
# 100/100 [==============================] - 0s 65us/step - loss: 0.2778 - mse: 0.2778
# Epoch 9/20
# 100/100 [==============================] - 0s 62us/step - loss: 0.2778 - mse: 0.2778
# Epoch 10/20
# 100/100 [==============================] - 0s 53us/step - loss: 0.2778 - mse: 0.2778
# Epoch 11/20
# 100/100 [==============================] - 0s 71us/step - loss: 0.2778 - mse: 0.2778
# Epoch 12/20
# 100/100 [==============================] - 0s 56us/step - loss: 0.2778 - mse: 0.2778
# Epoch 13/20
# 100/100 [==============================] - 0s 63us/step - loss: 0.2778 - mse: 0.2778
# Epoch 14/20
# 100/100 [==============================] - 0s 58us/step - loss: 0.2778 - mse: 0.2778
# Epoch 15/20
# 100/100 [==============================] - 0s 67us/step - loss: 0.2778 - mse: 0.2778
# Epoch 16/20
# 100/100 [==============================] - 0s 54us/step - loss: 0.2778 - mse: 0.2778
# Epoch 17/20
# 100/100 [==============================] - 0s 72us/step - loss: 0.2778 - mse: 0.2778
# Epoch 18/20
# 100/100 [==============================] - 0s 57us/step - loss: 0.2778 - mse: 0.2778
# Epoch 19/20
# 100/100 [==============================] - 0s 68us/step - loss: 0.2778 - mse: 0.2778
# Epoch 20/20
# 100/100 [==============================] - 0s 49us/step - loss: 0.2778 - mse: 0.2778

# %%
y_preds = model.predict(X_train)

# %%
SpatialPlot(X_train, y_train, y_preds)

# %%
a = np.array([[[1],
               [2],
               [3]],
              [[2],
               [3],
               [4]]])
b = a/1.5

# %%
np.sum(-a*np.log(b))
# Out:
# -8.827463277105535
